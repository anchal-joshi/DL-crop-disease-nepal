# %%
# ============================================================
# 04_transfer_learning.ipynb - Transfer Learning with EfficientNetB0
# ============================================================

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
from sklearn.metrics import classification_report, confusion_matrix

print("All imports successful!")
print("TensorFlow version:", tf.__version__)
# Out:
# All imports successful!
# TensorFlow version: 2.20.0

# %%
# ── Config ───────────────────────────────────────────────────
IMG_SIZE        = (224, 224)
BATCH_SIZE      = 32
EPOCHS_FROZEN   = 10
EPOCHS_FINETUNE = 20
LR_FROZEN       = 1e-3
LR_FINETUNE     = 1e-5
MODEL_DIR       = Path("../models")
RESULT_DIR      = Path("../results")
SPLIT_DIR       = Path("../data/PlantVillage_split")

class_names       = np.load(MODEL_DIR / "class_names.npy", allow_pickle=True)
class_weights     = np.load(MODEL_DIR / "class_weights.npy")
class_weight_dict = dict(enumerate(class_weights))
NUM_CLASSES       = len(class_names)
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Number of classes: 15

# %%
# ── Generators ───────────────────────────────────────────────
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2  # Use 20% for validation
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Use the PlantVillage folder
SPLIT_DIR = Path("../data/PlantVillage")

# Create generators with train/val split
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'  # 80% for training
)

val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'  # 20% for validation
)

# For test (use the same directory for now)
test_gen = test_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("Data generators created successfully!")
print(f"Training samples: {train_gen.samples}")
print(f"Validation samples: {val_gen.samples}")
print(f"Test samples: {test_gen.samples}")
# Out:
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Found 20638 images belonging to 15 classes.
# Data generators created successfully!
# Training samples: 16516
# Validation samples: 0
# Test samples: 20638

# %%
# ── Build Transfer Learning Model ────────────────────────────
def build_transfer_model(num_classes):
    base = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(224, 224, 3)
    )
    base.trainable = False  # Freeze for Phase 1

    inputs = layers.Input(shape=(224, 224, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs, name="efficientnet_b0")
    return model, base

tl_model, base_model = build_transfer_model(NUM_CLASSES)
tl_model.summary()
print("Model built successfully!")
# Out:
# Model: "efficientnet_b0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# Check dataset details
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")

print(f"Path exists: {SPLIT_DIR.exists()}")
print(f"Is directory: {SPLIT_DIR.is_dir()}")

if SPLIT_DIR.exists():
    # Count folders inside
    folders = [f for f in SPLIT_DIR.iterdir() if f.is_dir()]
    print(f"Number of class folders: {len(folders)}")
    print(f"First 5 folders: {[f.name for f in folders[:5]]}")
    
    # Check if there are images inside
    total_images = 0
    for folder in folders:
        images = list(folder.glob("*.jpg")) + list(folder.glob("*.png")) + list(folder.glob("*.JPG"))
        total_images += len(images)
        if len(images) > 0:
            print(f"  {folder.name}: {len(images)} images")
    print(f"Total images found: {total_images}")
else:
    print("PlantVillage folder not found in ../data/")
# Out:
# Path exists: True
# Is directory: True
# Number of class folders: 15
# First 5 folders: ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
#   Pepper__bell___Bacterial_spot: 1994 images
#   Pepper__bell___healthy: 2955 images
#   Potato___Early_blight: 2000 images
#   Potato___healthy: 304 images
#   Potato___Late_blight: 2000 images
#   Tomato_Bacterial_spot: 4254 images
#   Tomato_Early_blight: 2000 images
#   Tomato_healthy: 3182 images
#   Tomato_Late_blight: 3816 images
#   Tomato_Leaf_Mold: 1904 images
#   Tomato_Septoria_leaf_spot: 3542 images
#   Tomato_Spider_mites_Two_spotted_spider_mite: 3352 images
#   Tomato__Target_Spot: 2808 images
#   Tomato__Tomato_mosaic_virus: 746 images
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 6416 images
# Total images found: 41273

# %%
from pathlib import Path

MODEL_DIR = Path("../models")
print(f"models folder exists: {MODEL_DIR.exists()}")

if MODEL_DIR.exists():
    print("\nFiles in models folder:")
    for item in MODEL_DIR.iterdir():
        print(f"  - {item.name}")
    
    # Check specific files
    class_names_file = MODEL_DIR / "class_names.npy"
    class_weights_file = MODEL_DIR / "class_weights.npy"
    print(f"\nclass_names.npy exists: {class_names_file.exists()}")
    print(f"class_weights.npy exists: {class_weights_file.exists()}")
else:
    print("models folder does not exist!")
# Out:
# models folder exists: True
#
# Files in models folder:
#   - .gitkeep
#   - baseline_cnn_best.keras
#   - baseline_cnn_final.keras
#   - class_names.npy
#   - class_weights.npy
#   - tl_best.keras
#   - tl_phase1_best.keras
#
# class_names.npy exists: True
# class_weights.npy exists: True

# %%
# ── Recreate Generators ──────────────────────────────────────
print("Recreating generators...")

# Reset the generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Use the PlantVillage folder
SPLIT_DIR = Path("../data/PlantVillage")

# Create generators with train/val split
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'
)

val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'
)

# For test (use the same directory for now)
test_gen = test_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print(f"Training samples: {train_gen.samples}")
print(f"Validation samples: {val_gen.samples}")
print(f"Test samples: {test_gen.samples}")
print("Generators recreated successfully!")
# Out:
# Recreating generators...
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Found 20638 images belonging to 15 classes.
# Training samples: 16516
# Validation samples: 0
# Test samples: 20638
# Generators recreated successfully!

# %%
# Test the generator
print("Testing generator...")

try:
    # Get one batch
    batch_x, batch_y = next(train_gen)
    print(f" Batch shape: {batch_x.shape}")
    print(f" Labels shape: {batch_y.shape}")
    print(" Generator is working correctly!")
    
    # Check class distribution
    print(f"\nClass names: {class_names[:5]}...")
    print(f"Total classes: {len(class_names)}")
    
except Exception as e:
    print(f" Error: {e}")
# Out:
# Testing generator...
#  Batch shape: (32, 224, 224, 3)
#  Labels shape: (32, 15)
#  Generator is working correctly!
#
# Class names: ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy']...
# Total classes: 15

# %%
print("Train generator length:", len(train_gen))
print("Validation generator length:", len(val_gen))
print("Test generator length:", len(test_gen))
print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
# Out:
# Train generator length: 517
# Validation generator length: 0
# Test generator length: 645
# Train samples: 16516
# Validation samples: 0

# %%
print("Class weight dict:", class_weight_dict)
print("Number of classes:", NUM_CLASSES)
print("Class names:", class_names)
# Out:
# Class weight dict: {0: np.float32(0.9014638), 1: np.float32(0.8980833), 2: np.float32(0.8980833), 3: np.float32(0.8980833), 4: np.float32(5.9377413), 5: np.float32(0.8980833), 6: np.float32(0.8980833), 7: np.float32(0.8980833), 8: np.float32(0.9441086), 9: np.float32(0.8980833), 10: np.float32(0.8980833), 11: np.float32(0.8980833), 12: np.float32(0.8980833), 13: np.float32(2.4109619), 14: np.float32(0.8980833)}
# Number of classes: 15
# Class names: ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy'
#  'Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites_Two_spotted_spider_mite' 'Tomato__Target_Spot'
#  'Tomato__Tomato_YellowLeaf__Curl_Virus' 'Tomato__Tomato_mosaic_virus'
#  'Tomato_healthy']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Create data generators with validation split
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2  # 20% for validation
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Training generator (80% of data)
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'  # This should work if validation_split is set
)

# Validation generator (20% of data)
val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'
)

print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
# Out:
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Train samples: 16516
# Validation samples: 0

# %%
import os
import shutil
import random
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")
TRAIN_DIR = Path("../data/train")
VAL_DIR = Path("../data/val")
TEST_DIR = Path("../data/test")

# Create directories
TRAIN_DIR.mkdir(exist_ok=True)
VAL_DIR.mkdir(exist_ok=True)
TEST_DIR.mkdir(exist_ok=True)

# Split ratio
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Get all class folders
class_folders = [f for f in SPLIT_DIR.iterdir() if f.is_dir()]

for class_folder in class_folders:
    class_name = class_folder.name
    
    # Create class subfolders in train/val/test
    (TRAIN_DIR / class_name).mkdir(exist_ok=True)
    (VAL_DIR / class_name).mkdir(exist_ok=True)
    (TEST_DIR / class_name).mkdir(exist_ok=True)
    
    # Get all images in this class
    images = list(class_folder.glob("*.jpg")) + list(class_folder.glob("*.png")) + list(class_folder.glob("*.JPG"))
    random.shuffle(images)
    
    total = len(images)
    train_end = int(total * train_ratio)
    val_end = int(total * (train_ratio + val_ratio))
    
    # Copy images to train folder
    for img in images[:train_end]:
        shutil.copy(img, TRAIN_DIR / class_name / img.name)
    
    # Copy images to val folder
    for img in images[train_end:val_end]:
        shutil.copy(img, VAL_DIR / class_name / img.name)
    
    # Copy images to test folder
    for img in images[val_end:]:
        shutil.copy(img, TEST_DIR / class_name / img.name)
    
    print(f"{class_name}: {total} images -> Train: {train_end}, Val: {val_end - train_end}, Test: {total - val_end}")

print("Data split complete!")
# Out:
# Pepper__bell___Bacterial_spot: 1994 images -> Train: 1395, Val: 299, Test: 300
# Pepper__bell___healthy: 2955 images -> Train: 2068, Val: 443, Test: 444
# Potato___Early_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Potato___healthy: 304 images -> Train: 212, Val: 46, Test: 46
# Potato___Late_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Tomato_Bacterial_spot: 4254 images -> Train: 2977, Val: 638, Test: 639
# Tomato_Early_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Tomato_healthy: 3182 images -> Train: 2227, Val: 477, Test: 478
# Tomato_Late_blight: 3816 images -> Train: 2671, Val: 572, Test: 573
# Tomato_Leaf_Mold: 1904 images -> Train: 1332, Val: 286, Test: 286
# Tomato_Septoria_leaf_spot: 3542 images -> Train: 2479, Val: 531, Test: 532
# Tomato_Spider_mites_Two_spotted_spider_mite: 3352 images -> Train: 2346, Val: 503, Test: 503
# Tomato__Target_Spot: 2808 images -> Train: 1965, Val: 421, Test: 422
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# New data paths
TRAIN_DIR = Path("../data/train")
VAL_DIR = Path("../data/val")
TEST_DIR = Path("../data/test")

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest"
)

# No augmentation for validation and test
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

val_gen = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
print("Test samples:", test_gen.samples)
# Out:
# Found 20484 images belonging to 15 classes.
# Found 9899 images belonging to 15 classes.
# Found 9862 images belonging to 15 classes.
# Train samples: 20484
# Validation samples: 9899
# Test samples: 9862

# %%
print("Train generator length:", len(train_gen))
print("Validation generator length:", len(val_gen))
print("Test generator length:", len(test_gen))
# Out:
# Train generator length: 641
# Validation generator length: 310
# Test generator length: 309

# %%
# ── PHASE 1: Train head only (base frozen) ───────────────────
print("\n=== PHASE 1: Training head only (base frozen) ===")

tl_model.compile(
    optimizer=Adam(learning_rate=LR_FROZEN),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

cb_p1 = [
    callbacks.EarlyStopping(
        monitor="val_loss", patience=5,
        restore_best_weights=True, verbose=1
    ),
    callbacks.ModelCheckpoint(
        MODEL_DIR / "tl_phase1_best.keras",
        monitor="val_accuracy",
        save_best_only=True, verbose=1
    ),
    callbacks.CSVLogger(str(RESULT_DIR / "tl_phase1_log.csv"))
]

history_p1 = tl_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_FROZEN,
    callbacks=cb_p1,
    verbose=1
)

print("Phase 1 training complete!")
# Out:
# === PHASE 1: Training head only (base frozen) ===
# Epoch 1/10
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.1091 - loss: 2.8396 - precision: 0.1314 - recall: 0.0052
# Epoch 1: val_accuracy improved from None to 0.15426, saving model to ..\models\tl_phase1_best.keras
#
# Epoch 1: finished saving model to ..\models\tl_phase1_best.keras
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 305s 464ms/step - accuracy: 0.1229 - loss: 2.7114 - precision: 0.1318 - recall: 0.0019 - val_accuracy: 0.1543 - val_loss: 2.6406 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.1493 - loss: 2.5965 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_accuracy did not improve from 0.15426
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 300s 468ms/step - accuracy: 0.1513 - loss: 2.5935 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1543 - val_loss: 2.6138 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/10
# ...

# %%
print("=== PHASE 2: Fine-tuning top 30 layers ===")

base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in tl_model.layers if l.trainable)
print(f"Trainable layers after unfreezing: {trainable_count}")

tl_model.compile(
    optimizer=Adam(learning_rate=LR_FINETUNE),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

cb_p2 = [
    callbacks.EarlyStopping(
        monitor="val_loss", patience=7,
        restore_best_weights=True, verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5,
        patience=3, min_lr=1e-7, verbose=1
    ),
    callbacks.ModelCheckpoint(
        MODEL_DIR / "tl_best.keras",
        monitor="val_accuracy",
        save_best_only=True, verbose=1
    ),
    callbacks.CSVLogger(str(RESULT_DIR / "tl_phase2_log.csv"))
]

history_p2 = tl_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_FINETUNE,
    callbacks=cb_p2,
    verbose=1
)

print("Phase 2 training complete!")
# Out:
# === PHASE 2: Fine-tuning top 30 layers ===
# Trainable layers after unfreezing: 9
# Epoch 1/20
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.1456 - loss: 2.6139 - precision: 0.0156 - recall: 1.9351e-05
# Epoch 1: val_accuracy improved from None to 0.15426, saving model to ..\models\tl_best.keras
#
# Epoch 1: finished saving model to ..\models\tl_best.keras
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 315s 477ms/step - accuracy: 0.1516 - loss: 2.5862 - precision: 0.0476 - recall: 4.8819e-05 - val_accuracy: 0.1543 - val_loss: 2.5713 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 2/20
# 641/641 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.1551 - loss: 2.5702 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_accuracy did not improve from 0.15426
# ...

# %%
# ── Save final model ─────────────────────────────────────────
tl_model.save(MODEL_DIR / "tl_final.keras")
print("Saved → models/tl_final.keras")

# ── Combine and save full history ────────────────────────────
combined_history = {}
for k in history_p1.history:
    p1_vals = [float(v) for v in history_p1.history[k]]
    p2_vals = [float(v) for v in history_p2.history.get(k, [])]
    combined_history[k] = p1_vals + p2_vals

with open(RESULT_DIR / "tl_history.json", "w") as f:
    json.dump(combined_history, f)
print("Saved → results/tl_history.json")
# Out:
# Saved → models/tl_final.keras
# Saved → results/tl_history.json

# %%
# ── Plot combined curves ──────────────────────────────────────
total_p1 = len(history_p1.history["accuracy"])

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(combined_history["accuracy"],     label="Train")
axes[0].plot(combined_history["val_accuracy"], label="Validation")
axes[0].axvline(x=total_p1, color="red",
                linestyle="--", label="Fine-tune starts")
axes[0].set_title("EfficientNetB0 — Accuracy (Both Phases)")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].legend()
axes[0].grid(True)

axes[1].plot(combined_history["loss"],     label="Train")
axes[1].plot(combined_history["val_loss"], label="Validation")
axes[1].axvline(x=total_p1, color="red",
                linestyle="--", label="Fine-tune starts")
axes[1].set_title("EfficientNetB0 — Loss (Both Phases)")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.savefig(RESULT_DIR / "tl_training_curves.png", dpi=150)
plt.show()
print("Saved → results/tl_training_curves.png")
# Out:
# Saved → results/tl_training_curves.png

# %%
test_gen.reset()
results = tl_model.evaluate(test_gen, verbose=1)
metric_names = tl_model.metrics_names
for name, val in zip(metric_names, results):
    print(f"  {name:15s}: {val:.4f}")
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 74s 240ms/step - accuracy: 0.1550 - loss: 2.4240 - precision: 0.0000e+00 - recall: 0.0000e+00
#   loss           : 2.4240
#   compile_metrics: 0.1550

# %%
test_gen.reset()
pred_probs = tl_model.predict(test_gen, verbose=1)
y_pred_tl  = np.argmax(pred_probs, axis=1)
y_true     = test_gen.classes
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 74s 235ms/step

# %%
print("\nClassification Report:")
print(classification_report(
    y_true, y_pred_tl,
    target_names=class_names
))
# Out:
# Classification Report:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.00      0.00      0.00       472
#                      Pepper__bell___healthy       0.00      0.00      0.00       714
#                       Potato___Early_blight       0.00      0.00      0.00       485
#                        Potato___Late_blight       0.00      0.00      0.00       485
#                            Potato___healthy       0.00      0.00      0.00        75
#                       Tomato_Bacterial_spot       0.00      0.00      0.00      1019
#                         Tomato_Early_blight       0.00      0.00      0.00       482
#                          Tomato_Late_blight       0.00      0.00      0.00       904
#                            Tomato_Leaf_Mold       0.00      0.00      0.00       447
#                   Tomato_Septoria_leaf_spot       0.00      0.00      0.00       848
# ...

# %%
cm = confusion_matrix(y_true, y_pred_tl)
plt.figure(figsize=(16, 14))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Greens",
    xticklabels=class_names,
    yticklabels=class_names,
    annot_kws={"size": 7}
)
plt.title("EfficientNetB0 Transfer Learning — Confusion Matrix", fontsize=14)
plt.ylabel("True Label", fontsize=12)
plt.xlabel("Predicted Label", fontsize=12)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(rotation=0,  fontsize=7)
plt.tight_layout()
plt.savefig(RESULT_DIR / "tl_confusion_matrix.png", dpi=150)
plt.show()
print("Saved → results/tl_confusion_matrix.png")
print("\nTransfer learning complete → next: 05_evaluation.ipynb")
# Out:
# Saved → results/tl_confusion_matrix.png
#
# Transfer learning complete → next: 05_evaluation.ipynb
