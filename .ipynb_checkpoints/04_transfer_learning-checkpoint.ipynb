# %%
# ============================================================
# 04_transfer_learning.ipynb - Transfer Learning with EfficientNetB0
# ============================================================

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
from sklearn.metrics import classification_report, confusion_matrix

print("All imports successful!")
print("TensorFlow version:", tf.__version__)
# Out:
# C:\Users\LOQ\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# All imports successful!
# TensorFlow version: 2.20.0

# %%
# ── Config ───────────────────────────────────────────────────
IMG_SIZE        = (224, 224)
BATCH_SIZE      = 32
EPOCHS_FROZEN   = 10
EPOCHS_FINETUNE = 20
LR_FROZEN       = 1e-3
LR_FINETUNE     = 1e-5
MODEL_DIR       = Path("../models")
RESULT_DIR      = Path("../results")
SPLIT_DIR       = Path("../data/PlantVillage_split")

class_names       = np.load(MODEL_DIR / "class_names.npy", allow_pickle=True)
class_weights     = np.load(MODEL_DIR / "class_weights.npy")
class_weight_dict = dict(enumerate(class_weights))
NUM_CLASSES       = len(class_names)
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Number of classes: 15

# %%
# ── Generators ───────────────────────────────────────────────
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2  # Use 20% for validation
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Use the PlantVillage folder
SPLIT_DIR = Path("../data/PlantVillage")

# Create generators with train/val split
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'  # 80% for training
)

val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'  # 20% for validation
)

# For test (use the same directory for now)
test_gen = test_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("Data generators created successfully!")
print(f"Training samples: {train_gen.samples}")
print(f"Validation samples: {val_gen.samples}")
print(f"Test samples: {test_gen.samples}")
# Out:
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Found 20638 images belonging to 15 classes.
# Data generators created successfully!
# Training samples: 16516
# Validation samples: 0
# Test samples: 20638

# %%
# ── Build Transfer Learning Model ────────────────────────────
def build_transfer_model(num_classes):
    base = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(224, 224, 3)
    )
    base.trainable = False  # Freeze for Phase 1

    inputs = layers.Input(shape=(224, 224, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs, name="efficientnet_b0")
    return model, base

tl_model, base_model = build_transfer_model(NUM_CLASSES)
tl_model.summary()
print("Model built successfully!")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "efficientnet_b0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         655,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 15)                  │           3,855 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,845,746 (18.49 MB)
#  Trainable params: 793,615 (3.03 MB)
#  Non-trainable params: 4,052,131 (15.46 MB)
# Model built successfully!

# %%
# Check dataset details
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")

print(f"Path exists: {SPLIT_DIR.exists()}")
print(f"Is directory: {SPLIT_DIR.is_dir()}")

if SPLIT_DIR.exists():
    # Count folders inside
    folders = [f for f in SPLIT_DIR.iterdir() if f.is_dir()]
    print(f"Number of class folders: {len(folders)}")
    print(f"First 5 folders: {[f.name for f in folders[:5]]}")
    
    # Check if there are images inside
    total_images = 0
    for folder in folders:
        images = list(folder.glob("*.jpg")) + list(folder.glob("*.png")) + list(folder.glob("*.JPG"))
        total_images += len(images)
        if len(images) > 0:
            print(f"  {folder.name}: {len(images)} images")
    print(f"Total images found: {total_images}")
else:
    print("PlantVillage folder not found in ../data/")
# Out:
# Path exists: True
# Is directory: True
# Number of class folders: 15
# First 5 folders: ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
#   Pepper__bell___Bacterial_spot: 1994 images
#   Pepper__bell___healthy: 2955 images
#   Potato___Early_blight: 2000 images
#   Potato___healthy: 304 images
#   Potato___Late_blight: 2000 images
#   Tomato_Bacterial_spot: 4254 images
#   Tomato_Early_blight: 2000 images
#   Tomato_healthy: 3182 images
#   Tomato_Late_blight: 3816 images
#   Tomato_Leaf_Mold: 1904 images
#   Tomato_Septoria_leaf_spot: 3542 images
#   Tomato_Spider_mites_Two_spotted_spider_mite: 3352 images
#   Tomato__Target_Spot: 2808 images
#   Tomato__Tomato_mosaic_virus: 746 images
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 6416 images
# Total images found: 41273

# %%
from pathlib import Path

MODEL_DIR = Path("../models")
print(f"models folder exists: {MODEL_DIR.exists()}")

if MODEL_DIR.exists():
    print("\nFiles in models folder:")
    for item in MODEL_DIR.iterdir():
        print(f"  - {item.name}")
    
    # Check specific files
    class_names_file = MODEL_DIR / "class_names.npy"
    class_weights_file = MODEL_DIR / "class_weights.npy"
    print(f"\nclass_names.npy exists: {class_names_file.exists()}")
    print(f"class_weights.npy exists: {class_weights_file.exists()}")
else:
    print("models folder does not exist!")
# Out:
# models folder exists: True
#
# Files in models folder:
#   - .gitkeep
#   - baseline_cnn_best.keras
#   - baseline_cnn_final.keras
#   - class_names.npy
#   - class_weights.npy
#
# class_names.npy exists: True
# class_weights.npy exists: True

# %%
# ── Recreate Generators ──────────────────────────────────────
print("Recreating generators...")

# Reset the generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Use the PlantVillage folder
SPLIT_DIR = Path("../data/PlantVillage")

# Create generators with train/val split
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'
)

val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'
)

# For test (use the same directory for now)
test_gen = test_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print(f"Training samples: {train_gen.samples}")
print(f"Validation samples: {val_gen.samples}")
print(f"Test samples: {test_gen.samples}")
print("Generators recreated successfully!")
# Out:
# Recreating generators...
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Found 20638 images belonging to 15 classes.
# Training samples: 16516
# Validation samples: 0
# Test samples: 20638
# Generators recreated successfully!

# %%
# Test the generator
print("Testing generator...")

try:
    # Get one batch
    batch_x, batch_y = next(train_gen)
    print(f" Batch shape: {batch_x.shape}")
    print(f" Labels shape: {batch_y.shape}")
    print(" Generator is working correctly!")
    
    # Check class distribution
    print(f"\nClass names: {class_names[:5]}...")
    print(f"Total classes: {len(class_names)}")
    
except Exception as e:
    print(f" Error: {e}")
# Out:
# Testing generator...
#  Batch shape: (32, 224, 224, 3)
#  Labels shape: (32, 15)
#  Generator is working correctly!
#
# Class names: ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy']...
# Total classes: 15

# %%
print("Train generator length:", len(train_gen))
print("Validation generator length:", len(val_gen))
print("Test generator length:", len(test_gen))
print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
# Out:
# Train generator length: 517
# Validation generator length: 0
# Test generator length: 645
# Train samples: 16516
# Validation samples: 0

# %%
print("Class weight dict:", class_weight_dict)
print("Number of classes:", NUM_CLASSES)
print("Class names:", class_names)
# Out:
# Class weight dict: {0: np.float32(0.9014638), 1: np.float32(0.8980833), 2: np.float32(0.8980833), 3: np.float32(0.8980833), 4: np.float32(5.9377413), 5: np.float32(0.8980833), 6: np.float32(0.8980833), 7: np.float32(0.8980833), 8: np.float32(0.9441086), 9: np.float32(0.8980833), 10: np.float32(0.8980833), 11: np.float32(0.8980833), 12: np.float32(0.8980833), 13: np.float32(2.4109619), 14: np.float32(0.8980833)}
# Number of classes: 15
# Class names: ['Pepper__bell___Bacterial_spot' 'Pepper__bell___healthy'
#  'Potato___Early_blight' 'Potato___Late_blight' 'Potato___healthy'
#  'Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites_Two_spotted_spider_mite' 'Tomato__Target_Spot'
#  'Tomato__Tomato_YellowLeaf__Curl_Virus' 'Tomato__Tomato_mosaic_virus'
#  'Tomato_healthy']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Create data generators with validation split
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest",
    validation_split=0.2  # 20% for validation
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Training generator (80% of data)
train_gen = train_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42,
    subset='training'  # This should work if validation_split is set
)

# Validation generator (20% of data)
val_gen = val_datagen.flow_from_directory(
    SPLIT_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    seed=42,
    subset='validation'
)

print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
# Out:
# Found 16516 images belonging to 15 classes.
# Found 0 images belonging to 15 classes.
# Train samples: 16516
# Validation samples: 0

# %%
import os
import shutil
import random
from pathlib import Path

SPLIT_DIR = Path("../data/PlantVillage")
TRAIN_DIR = Path("../data/train")
VAL_DIR = Path("../data/val")
TEST_DIR = Path("../data/test")

# Create directories
TRAIN_DIR.mkdir(exist_ok=True)
VAL_DIR.mkdir(exist_ok=True)
TEST_DIR.mkdir(exist_ok=True)

# Split ratio
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Get all class folders
class_folders = [f for f in SPLIT_DIR.iterdir() if f.is_dir()]

for class_folder in class_folders:
    class_name = class_folder.name
    
    # Create class subfolders in train/val/test
    (TRAIN_DIR / class_name).mkdir(exist_ok=True)
    (VAL_DIR / class_name).mkdir(exist_ok=True)
    (TEST_DIR / class_name).mkdir(exist_ok=True)
    
    # Get all images in this class
    images = list(class_folder.glob("*.jpg")) + list(class_folder.glob("*.png")) + list(class_folder.glob("*.JPG"))
    random.shuffle(images)
    
    total = len(images)
    train_end = int(total * train_ratio)
    val_end = int(total * (train_ratio + val_ratio))
    
    # Copy images to train folder
    for img in images[:train_end]:
        shutil.copy(img, TRAIN_DIR / class_name / img.name)
    
    # Copy images to val folder
    for img in images[train_end:val_end]:
        shutil.copy(img, VAL_DIR / class_name / img.name)
    
    # Copy images to test folder
    for img in images[val_end:]:
        shutil.copy(img, TEST_DIR / class_name / img.name)
    
    print(f"{class_name}: {total} images -> Train: {train_end}, Val: {val_end - train_end}, Test: {total - val_end}")

print("Data split complete!")
# Out:
# Pepper__bell___Bacterial_spot: 1994 images -> Train: 1395, Val: 299, Test: 300
# Pepper__bell___healthy: 2955 images -> Train: 2068, Val: 443, Test: 444
# Potato___Early_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Potato___healthy: 304 images -> Train: 212, Val: 46, Test: 46
# Potato___Late_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Tomato_Bacterial_spot: 4254 images -> Train: 2977, Val: 638, Test: 639
# Tomato_Early_blight: 2000 images -> Train: 1400, Val: 300, Test: 300
# Tomato_healthy: 3182 images -> Train: 2227, Val: 477, Test: 478
# Tomato_Late_blight: 3816 images -> Train: 2671, Val: 572, Test: 573
# Tomato_Leaf_Mold: 1904 images -> Train: 1332, Val: 286, Test: 286
# Tomato_Septoria_leaf_spot: 3542 images -> Train: 2479, Val: 531, Test: 532
# Tomato_Spider_mites_Two_spotted_spider_mite: 3352 images -> Train: 2346, Val: 503, Test: 503
# Tomato__Target_Spot: 2808 images -> Train: 1965, Val: 421, Test: 422
# Tomato__Tomato_mosaic_virus: 746 images -> Train: 522, Val: 112, Test: 112
# Tomato__Tomato_YellowLeaf__Curl_Virus: 6416 images -> Train: 4491, Val: 962, Test: 963
# Data split complete!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# New data paths
TRAIN_DIR = Path("../data/train")
VAL_DIR = Path("../data/val")
TEST_DIR = Path("../data/test")

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode="nearest"
)

# No augmentation for validation and test
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create generators
train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

val_gen = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
print("Test samples:", test_gen.samples)
# Out:
# Found 18770 images belonging to 15 classes.
# Found 5723 images belonging to 15 classes.
# Found 5744 images belonging to 15 classes.
# Train samples: 18770
# Validation samples: 5723
# Test samples: 5744

# %%
print("Train generator length:", len(train_gen))
print("Validation generator length:", len(val_gen))
print("Test generator length:", len(test_gen))
# Out:
# Train generator length: 587
# Validation generator length: 179
# Test generator length: 180

# %%
# ── PHASE 1: Train head only (base frozen) ───────────────────
print("\n=== PHASE 1: Training head only (base frozen) ===")

tl_model.compile(
    optimizer=Adam(learning_rate=LR_FROZEN),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

cb_p1 = [
    callbacks.EarlyStopping(
        monitor="val_loss", patience=5,
        restore_best_weights=True, verbose=1
    ),
    callbacks.ModelCheckpoint(
        MODEL_DIR / "tl_phase1_best.keras",
        monitor="val_accuracy",
        save_best_only=True, verbose=1
    ),
    callbacks.CSVLogger(str(RESULT_DIR / "tl_phase1_log.csv"))
]

history_p1 = tl_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_FROZEN,
    callbacks=cb_p1,
    verbose=1
)

print("Phase 1 training complete!")
# Out:
# === PHASE 1: Training head only (base frozen) ===
# Epoch 1/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.1523 - loss: 2.6004 - precision: 0.2799 - recall: 7.4708e-05
# Epoch 1: val_accuracy improved from None to 0.15359, saving model to ..\models\tl_phase1_best.keras
#
# Epoch 1: finished saving model to ..\models\tl_phase1_best.keras
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 252s 419ms/step - accuracy: 0.1544 - loss: 2.5913 - precision: 0.1250 - recall: 5.3277e-05 - val_accuracy: 0.1536 - val_loss: 2.5772 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.1524 - loss: 2.5944 - precision: 0.0379 - recall: 2.9829e-05
# Epoch 2: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 244s 415ms/step - accuracy: 0.1555 - loss: 2.5842 - precision: 0.0769 - recall: 5.3277e-05 - val_accuracy: 0.1536 - val_loss: 2.5816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.1516 - loss: 2.5810 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 244s 415ms/step - accuracy: 0.1552 - loss: 2.5752 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1536 - val_loss: 2.5787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.1568 - loss: 2.5710 - precision: 0.2421 - recall: 1.5395e-04
# Epoch 4: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 244s 415ms/step - accuracy: 0.1560 - loss: 2.5673 - precision: 0.1818 - recall: 1.0655e-04 - val_accuracy: 0.1536 - val_loss: 2.5735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.1578 - loss: 2.5572 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 243s 414ms/step - accuracy: 0.1552 - loss: 2.5602 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1536 - val_loss: 2.5716 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.1587 - loss: 2.5550 - precision: 0.2362 - recall: 1.5749e-04
# Epoch 6: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 244s 416ms/step - accuracy: 0.1587 - loss: 2.5478 - precision: 0.3000 - recall: 1.5983e-04 - val_accuracy: 0.1536 - val_loss: 2.5707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.1638 - loss: 2.5427 - precision: 0.0896 - recall: 3.6999e-05
# Epoch 7: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 242s 412ms/step - accuracy: 0.1624 - loss: 2.5314 - precision: 0.2222 - recall: 1.0655e-04 - val_accuracy: 0.1536 - val_loss: 2.5700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.1599 - loss: 2.5313 - precision: 0.4343 - recall: 2.6039e-04
# Epoch 8: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 242s 412ms/step - accuracy: 0.1624 - loss: 2.5255 - precision: 0.3846 - recall: 2.6638e-04 - val_accuracy: 0.1536 - val_loss: 2.5395 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.1647 - loss: 2.5181 - precision: 0.0937 - recall: 3.3732e-05
# Epoch 9: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 243s 415ms/step - accuracy: 0.1620 - loss: 2.5180 - precision: 0.4286 - recall: 1.5983e-04 - val_accuracy: 0.1536 - val_loss: 2.5155 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/10
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.1584 - loss: 2.5236 - precision: 0.6023 - recall: 3.4719e-04
# Epoch 10: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 251s 427ms/step - accuracy: 0.1633 - loss: 2.5147 - precision: 0.6667 - recall: 4.2621e-04 - val_accuracy: 0.1536 - val_loss: 2.5669 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Restoring model weights from the end of the best epoch: 9.
# Phase 1 training complete!

# %%
print("=== PHASE 2: Fine-tuning top 30 layers ===")

base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

trainable_count = sum(1 for l in tl_model.layers if l.trainable)
print(f"Trainable layers after unfreezing: {trainable_count}")

tl_model.compile(
    optimizer=Adam(learning_rate=LR_FINETUNE),
    loss="categorical_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

cb_p2 = [
    callbacks.EarlyStopping(
        monitor="val_loss", patience=7,
        restore_best_weights=True, verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5,
        patience=3, min_lr=1e-7, verbose=1
    ),
    callbacks.ModelCheckpoint(
        MODEL_DIR / "tl_best.keras",
        monitor="val_accuracy",
        save_best_only=True, verbose=1
    ),
    callbacks.CSVLogger(str(RESULT_DIR / "tl_phase2_log.csv"))
]

history_p2 = tl_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS_FINETUNE,
    callbacks=cb_p2,
    verbose=1
)

print("Phase 2 training complete!")
# Out:
# === PHASE 2: Fine-tuning top 30 layers ===
# Trainable layers after unfreezing: 9
# Epoch 1/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.1521 - loss: 2.6394 - precision: 0.0834 - recall: 6.3325e-04
# Epoch 1: val_accuracy improved from None to 0.15359, saving model to ..\models\tl_best.keras
#
# Epoch 1: finished saving model to ..\models\tl_best.keras
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 279s 459ms/step - accuracy: 0.1547 - loss: 2.5951 - precision: 0.1111 - recall: 2.6638e-04 - val_accuracy: 0.1536 - val_loss: 2.5696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 2/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.1530 - loss: 2.5706 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 268s 457ms/step - accuracy: 0.1557 - loss: 2.5708 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1536 - val_loss: 2.5696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 3/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.1539 - loss: 2.5693 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3: val_accuracy did not improve from 0.15359
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 267s 455ms/step - accuracy: 0.1556 - loss: 2.5658 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1536 - val_loss: 2.5696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 4/20
# 533/587 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - accuracy: 0.1577 - loss: 2.5637 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
from pathlib import Path
MODEL_DIR = Path("../models")
print("Files in models folder:")
for f in MODEL_DIR.iterdir():
    print(f"  {f.name}")
